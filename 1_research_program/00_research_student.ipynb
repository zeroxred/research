# %% [markdown]
# # 🔬 Research Student
#
# Insights for researching.
#
# ## Objectives
#
# - Improve japanese
# - Define research topic
# - Enter Ph.D program
#
# ## Insights
#
# -	Sensei will provide the information to enter Ph.D
# -	Vietnamese friend works in security, hence could help.
#
# ## Other possible researches
#
# - Agriculture: How to grown trees to get a particular fruit.
#     - Any video data required will be provided
# - Infraestructure: Progress of construction and how to build correctly.
#     - Any video data required will be provided
# - Medical: Cell Image analysis.
#     - Rebeka working on cell image analysis, image data could be provided.
#
# ## Tasks
#
# - Check related research:
#     - Datasets
#     - Public data and current research.
#     - Benchmark
#     - Particular data form class
#
# ## Questions
#
# - Expectations of research student
# - What are your expectations for me as a research student?
# - How often would you like me to report my progress?
# - Is there a preferred format for updates or meetings?
# - Is there a formal report I should submit at the end of the research program?
# PHD
# - What level of contribution would be expected before applying to the PhD program?
# - What would make me a strong candidate for the PhD in your lab?
